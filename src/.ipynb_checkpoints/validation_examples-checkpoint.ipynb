# %% [markdown]
# # Validation data visualization examples

# %% [markdown]
# ## Draw 3D detection box (annotated ground truth data)

# %%
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
import sys 
import os
sys.path.append('../src/')

from data_utils import *

# %%
# https://github.com/alexstaravoitau/KITTI-Dataset/blob/master/kitti-dataset.ipynb
# points == velo_frame

def draw_point_cloud(ax, velo_frame, title=None, axes=[0, 1, 2], point_size=0.1, xlim3d=None, ylim3d=None, zlim3d=None):
        """
        Convenient method for drawing various point cloud projections as a part of frame statistics.
        """
        axes_limits = [
                        [-20, 80], # X axis range
                        [-20, 20], # Y axis range
                        [-3, 3]   # Z axis range
                    ]
        axes_str = ['X', 'Y', 'Z']
        ax.grid(False)

    
        ax.scatter(*np.transpose(velo_frame[:, axes]), s=point_size, c=velo_frame[:, 3], cmap='gray')
        # ax.set_title(title)
        ax.set_xlabel('{} axis'.format(axes_str[axes[0]]))
        ax.set_ylabel('{} axis'.format(axes_str[axes[1]]))
        if len(axes) > 2:
            ax.set_xlim3d(*axes_limits[axes[0]])
            ax.set_ylim3d(*axes_limits[axes[1]])
            ax.set_zlim3d(*axes_limits[axes[2]])
            ax.set_zlabel('{} axis'.format(axes_str[axes[2]]))
        else:
            ax.set_xlim(*axes_limits[axes[0]])
            ax.set_ylim(*axes_limits[axes[1]])
        # User specified limits
        if xlim3d!=None:
            ax.set_xlim3d(xlim3d)
        if ylim3d!=None:
            ax.set_ylim3d(ylim3d)
        if zlim3d!=None:
            ax.set_zlim3d(zlim3d)

# %%
DATA_PATH = '/home/brwei01/Data/data_raw/2011_09_26/2011_09_26_drive_0005_sync/'

velo_frame = read_point_cloud(os.path.join(DATA_PATH, 'velodyne_points/data/%010d.bin'%0))

# %%
fig = plt.figure(figsize = (20, 10))
ax = fig.add_subplot(111,projection='3d')
ax.view_init(40, 150)
draw_point_cloud(ax, velo_frame[::5])

# %%
# plot bird view
fig, ax = plt.subplots(figsize=(20,10))
draw_point_cloud(ax, velo_frame[::5], axes=[0,1])

# %%
df_tracking = read_tracking('/home/brwei01/Data/data_label/training/label_02/0000.txt')
df_tracking.head()
# Out:
#    frame  track_id        type  truncated  occluded     alpha    bbox_left  \
# 2      0         0         Car          0         0 -1.793451   296.744956
# 3      0         1     Cyclist          0         0 -1.936993   737.619499
# 4      0         2  Pedestrian          0         0 -2.523309  1106.137292
# 7      1         0         Car          0         0 -1.796862   294.898777
# 8      1         1     Cyclist          0         0 -1.935205   745.017137
#
#      bbox_top   bbox_right  bbox_bottom    height     width    length  \
# 2  161.752147   455.226042   292.372804  2.000000  1.823255  4.433886
# 3  161.531951   931.112229   374.000000  1.739063  0.824591  1.785241
# 4  166.576807  1204.470628   323.876144  1.714062  0.767881  0.972283
# 7  156.024256   452.199718   284.621269  2.000000  1.823255  4.433886
# 8  156.393157   938.839722   374.000000  1.739063  0.824591  1.785241
#
#       pos_x     pos_y      pos_z     rot_y
# 2 -4.552284  1.858523  13.410495 -2.115488
# 3  1.640400  1.675660   5.776261 -1.675458
# 4  6.301919  1.652419   8.455685 -1.900245
# 7 -4.650955  1.766774  13.581085 -2.121565
# 8  1.700640  1.640419   5.778596 -1.664456

# %% [markdown]
# ## plot 3d detection box

# %%
# https://github.com/bostondiditeam/kitti/blob/master/resources/devkit_object/readme.txt

def compute_3d_box_cam2(h,w,l,x,y,z,yaw):
    '''
    Return: 3xn in cam2 coordinates
    '''
    R = np.array([[np.cos(yaw),0,np.sin(yaw)], [0,1,0], [-np.sin(yaw),0,np.cos(yaw)]])
    x_corners = [l/2,l/2,-l/2,-l/2,l/2,l/2,-l/2,-l/2]
    y_corners = [0,0,0,0,-h,-h,-h,-h]
    z_corners = [w/2,-w/2,-w/2,w/2,w/2,-w/2,-w/2,w/2]
    corners_3d_cam2 = np.dot(R, np.vstack([x_corners, y_corners, z_corners]))
    corners_3d_cam2 += np.vstack([x,y,z])
    return corners_3d_cam2

# %%
# code from: https://github.com/alexstaravoitau/KITTI-Dataset/blob/master/kitti-dataset.ipynb

def draw_box(pyplot_axis, vertices, axes=[0, 1, 2], color='black'):
    """
    Draws a bounding 3D box in a pyplot axis.
    
    Parameters
    ----------
    pyplot_axis : Pyplot axis to draw in.
    vertices    : Array 8 box vertices containing x, y, z coordinates.
    axes        : Axes to use. Defaults to `[0, 1, 2]`, e.g. x, y and z axes.
    color       : Drawing color. Defaults to `black`.
    """
    vertices = vertices[axes, :]
    connections = [
        [0, 1], [1, 2], [2, 3], [3, 0],  # Lower plane parallel to Z=0 plane
        [4, 5], [5, 6], [6, 7], [7, 4],  # Upper plane parallel to Z=0 plane
        [0, 4], [1, 5], [2, 6], [3, 7]  # Connections between upper and lower planes
    ]
    for connection in connections:
        pyplot_axis.plot(*vertices[:, connection], c=color, lw=0.5)

# %%
corners_3d_cam2 = compute_3d_box_cam2(*df_tracking.loc[2, ['height','width','length','pos_x','pos_y','pos_z','rot_y']])
corners_3d_cam2.shape
# Out:
# (3, 8)

# %%
fig = plt.figure(figsize=(20,10))
ax = fig.add_subplot(111, projection='3d')
ax.view_init(40,150)
draw_box(ax, (corners_3d_cam2))

# %% [markdown]
# ## proejct cam coords to velo coords

# %%
from kitti_utils import *

# %%
calib = Calibration('/home/brwei01/Data/data_raw/2011_09_26/', from_video=True)

corners_3d_velo = calib.project_rect_to_velo(corners_3d_cam2.T).T #rectify
corners_3d_velo
# Out:
# array([[15.12424719, 16.06928938, 12.27779014, 11.33274795, 15.10334837,
#         16.04839056, 12.25689133, 11.31184914],
#        [ 6.49985556,  4.9406537 ,  2.64287284,  4.2020747 ,  6.47872485,
#          4.91952299,  2.62174213,  4.18094399],
#        [-1.70710774, -1.71370686, -1.7776097 , -1.77101058,  0.29267156,
#          0.28607244,  0.2221696 ,  0.22876872]])

# %%
fig = plt.figure(figsize=(20,10))
ax = fig.add_subplot(111,projection='3d')
ax.view_init(40,150)
draw_box(ax, corners_3d_velo)

# %% [markdown]
# ## put into point cloud

# %%
fig = plt.figure(figsize=(20,10))
ax = fig.add_subplot(111,projection='3d')
ax.view_init(40,150)
draw_point_cloud(ax, velo_frame[::5])
draw_box(ax, corners_3d_velo)

# %%
fig, ax = plt.subplots(figsize=(20,10))
draw_point_cloud(ax, velo_frame[::5], axes=[0,1])
draw_box(ax, corners_3d_velo, axes=[0,1], color='r')

# %% [markdown]
# ## Calculation 1: From Annotatted bounding box

# %%
# ego car bbx (4936mm*1912mm)
ego_car_bbx = np.array([[2.15, 0.9, -1.73],[2.15, -0.9, -1.73],[-1.95, -0.9,-1.73],[-1.95,0.9,-1.73],
                        [2.15, 0.9, -0.23],[2.15, -0.9, -0.23],[-1.95, -0.9,-0.23],[-1.95,0.9,-0.23],
                       ])
plt.axes().set_aspect('equal', 'datalim')
plt.plot(ego_car_bbx[:5,0], ego_car_bbx[:5,1], '-o')
plt.plot(corners_3d_velo.T[:5, 0], corners_3d_velo.T[:5, 1], '-o')

# %%
fig, ax = plt.subplots(figsize=(20,10))
draw_point_cloud(ax, velo_frame[::5], axes=[0, 1])
draw_box(ax, corners_3d_velo, axes=[0,1], color='r')
draw_box(ax, ego_car_bbx.T, axes=[0,1],color='b')

# %%
def distance_point_to_segment(P,A,B):
    '''
    Calculates the min distance of a point to a segment AB
    Returns the point Q in AB on which the min distance can be found
    '''
    AP = P-A
    BP = P-B
    AB = B-A
    if np.dot(AB, AP) >= 0 and np.dot(-AB, BP) >= 0:
        return np.abs(np.cross(AP,AB))/np.linalg.norm(AB), np.dot(AP,AB)/np.dot(AB,AB)*AB + A
    d_PA = np.linalg.norm(AP)
    d_PB = np.linalg.norm(BP)
    if d_PA < d_PB:
        return d_PA, A
    return d_PB, B

# %%
P = np.array([4.5,2], dtype=np.float64)
# try with:
# P = np.array([1, 2], dtype=np.float64)
A = np.array([0,1], dtype=np.float64)
B = np.array([2,0], dtype=np.float64)
d, Q = distance_point_to_segment(P,A,B)

plt.axes().set_aspect('equal','datalim')
plt.scatter(P[0], P[1])
plt.plot(*zip(A, B), 'r-o')
plt.scatter(Q[0], Q[1], c='k')
plt.plot(*zip(P,Q), 'y-')
plt.show()
d
# Out:
# 3.2015621187164243

# %%
def min_distance_cuboids(cub1, cub2):
    '''
    Computes the minimum distance between two non-overlapping cuboids (3D) of shape(8,3)
    They are projected to BEV and the minimum distance of the two rectangles are return.
    '''
    minD = 1e5
    for i in range(4):
        for j in range(4):
            d, Q = distance_point_to_segment(cub1[i,:2], cub2[j,:2], cub2[j+1,:2])
            if d < minD:
                minD = d
                minP = cub1[i, :2]
                minQ = Q
    for i in range(4):
        for j in range(4):
            d, Q = distance_point_to_segment(cub2[i,:2], cub1[j,:2], cub1[j+1,:2])
            if d < minD:
                minD = d
                minP = cub2[i, :2]
                minQ = Q
    
    return minP, minQ, minD

# %%
ego_car_bbx, corners_3d_velo.T
# Out:
# (array([[ 2.15,  0.9 , -1.73],
#         [ 2.15, -0.9 , -1.73],
#         [-1.95, -0.9 , -1.73],
#         [-1.95,  0.9 , -1.73],
#         [ 2.15,  0.9 , -0.23],
#         [ 2.15, -0.9 , -0.23],
#         [-1.95, -0.9 , -0.23],
#         [-1.95,  0.9 , -0.23]]),
#  array([[15.12424719,  6.49985556, -1.70710774],
#         [16.06928938,  4.9406537 , -1.71370686],
#         [12.27779014,  2.64287284, -1.7776097 ],
#         [11.33274795,  4.2020747 , -1.77101058],
#         [15.10334837,  6.47872485,  0.29267156],
#         [16.04839056,  4.91952299,  0.28607244],
#         [12.25689133,  2.62174213,  0.2221696 ],
#         [11.31184914,  4.18094399,  0.22876872]]))

# %%
plt.axes().set_aspect('equal', 'datalim')
plt.plot(ego_car_bbx[:5, 0], ego_car_bbx[:5, 1],'-o')
plt.plot(corners_3d_velo.T[:5, 0], corners_3d_velo.T[:5, 1], '-o')
minP, minQ, minD = min_distance_cuboids(ego_car_bbx, corners_3d_velo.T)
plt.plot(*zip(minP, minQ), 'y-')
print(minD)
# Out:
# 9.75840956934395

# %% [markdown]
# ## Calculation 2: 2D point in polygon

# %%
import shapely
from shapely import Point, Polygon

ego_car_bbx = np.array([[2.15, 0.9, -1.73],[2.15, -0.9, -1.73],[-1.95, -0.9,-1.73],[-1.95,0.9,-1.73],
                        [2.15, 0.9, -0.23],[2.15, -0.9, -0.23],[-1.95, -0.9,-0.23],[-1.95,0.9,-0.23],
                       ])
ego_car_point = np.array([0,0,0])
ego_car_bbx_2d_coords = ego_car_bbx[:5,:2]
ego_car_bbx_2d = Polygon(ego_car_bbx_2d_coords)
print(ego_car_bbx_2d)
ego_car_bbx_2d
# Out:
# POLYGON ((2.15 0.9, 2.15 -0.9, -1.95 -0.9, -1.95 0.9, 2.15 0.9))
# <POLYGON ((2.15 0.9, 2.15 -0.9, -1.95 -0.9, -1.95 0.9, 2.15 0.9))>

# %%
corners_2d_velo_coords = corners_3d_velo.T[:5,:2]
box_2d_pcl = Polygon(corners_2d_velo_coords)
print(box_2d_pcl)
box_2d_pcl
# Out:
# POLYGON ((15.124247187238387 6.499855561568037, 16.069289375939935 4.94065369677543, 12.277790142688447 2.6428728370596977, 11.3327479539869 4.202074701852305, 15.10334836974831 6.4787248529891865, 15.124247187238387 6.499855561568037))
# <POLYGON ((15.124 6.5, 16.069 4.941, 12.278 2.643, 11.333 4.202, 15.103 6.47...>

# %%
points_in_box = []
for point_coords in velo_frame[::5][:,:2]:
    point = Point(point_coords)
    if point.within(box_2d_pcl):
        # print(point_coords)
        points_in_box.append(point_coords)

points_in_box = np.array(points_in_box)  # Convert the list of points to a NumPy array
points_in_box
# Out:
# array([[12.354,  3.113],
#        [12.246,  3.271],
#        [12.157,  3.432],
#        [12.046,  3.606],
#        [11.955,  3.764],
#        [11.872,  3.923],
#        [11.788,  4.102],
#        [12.376,  4.502],
#        [13.38 ,  3.564],
#        [14.037,  3.954],
#        [14.818,  4.529],
#        [14.758,  4.74 ],
#        [14.692,  4.949],
#        [11.968,  4.301],
#        [12.77 ,  4.796],
#        [13.831,  5.446],
#        [12.619,  3.011],
#        [14.426,  4.068],
#        [11.734,  4.146],
#        [14.307,  5.663],
#        [12.593,  2.994],
#        [14.429,  4.089],
#        [14.203,  4.437],
#        [12.874,  4.903],
#        [14.404,  5.83 ],
#        [12.196,  2.892],
#        [12.658,  3.381],
#        [13.419,  3.81 ],
#        [12.444,  3.768],
#        [13.159,  4.187],
#        [12.217,  4.123],
#        [11.596,  4.18 ],
#        [14.422,  5.762],
#        [12.522,  2.878],
#        [12.758,  3.251],
#        [12.533,  3.383],
#        [13.435,  3.879],
#        [12.403,  3.834],
#        [13.115,  4.26 ],
#        [11.673,  4.095],
#        [12.129,  4.493],
#        [13.627,  5.42 ],
#        [14.852,  6.209],
#        [13.415,  3.349],
#        [12.675,  3.378],
#        [13.416,  3.823],
#        [12.441,  3.781],
#        [13.189,  4.211],
#        [12.19 ,  4.17 ],
#        [12.857,  4.922],
#        [14.374,  5.838],
#        [12.442,  2.845],
#        [12.705,  3.244],
#        [12.589,  3.425],
#        [12.459,  3.58 ],
#        [12.044,  3.686],
#        [12.139,  3.904],
#        [12.159,  4.123],
#        [11.795,  4.269],
#        [13.22 ,  5.216],
#        [12.34 ,  2.816],
#        [12.233,  2.974],
#        [12.132,  3.132],
#        [12.029,  3.308],
#        [11.905,  3.496],
#        [11.816,  3.652],
#        [11.72 ,  3.805],
#        [11.638,  3.981],
#        [11.584,  4.147],
#        [12.089,  4.52 ],
#        [12.905,  5.055],
#        [13.999,  5.711],
#        [12.371,  2.828],
#        [12.268,  2.988],
#        [12.144,  3.16 ],
#        [12.044,  3.317],
#        [11.941,  3.47 ],
#        [11.864,  3.651],
#        [11.771,  3.805],
#        [11.68 ,  3.959],
#        [11.599,  4.115],
#        [11.912,  4.439],
#        [12.707,  4.943],
#        [13.749,  5.576],
#        [12.344,  2.816],
#        [12.22 ,  2.991],
#        [12.125,  3.15 ],
#        [12.013,  3.303],
#        [11.904,  3.476],
#        [11.818,  3.632],
#        [11.725,  3.786],
#        [11.639,  3.941],
#        [11.568,  4.121],
#        [11.825,  4.401],
#        [12.61 ,  4.895],
#        [13.575,  5.514],
#        [12.431,  2.8  ],
#        [12.301,  2.954],
#        [12.19 ,  3.11 ],
#        [12.08 ,  3.285],
#        [11.983,  3.441],
#        [11.889,  3.596],
#        [11.797,  3.751],
#        [11.707,  3.926],
#        [11.624,  4.082],
#        [11.707,  4.298],
#        [12.434,  4.79 ],
#        [13.401,  5.383],
#        [14.754,  6.174],
#        [12.261,  2.895],
#        [12.16 ,  3.073],
#        [12.046,  3.226],
#        [12.131,  3.434],
#        [11.845,  3.575],
#        [11.728,  3.742],
#        [11.65 ,  3.899],
#        [11.569,  4.055],
#        [11.62 ,  4.279],
#        [12.329,  4.737],
#        [13.337,  5.34 ],
#        [14.825,  6.231],
#        [12.328,  2.831],
#        [12.202,  2.984],
#        [12.104,  3.142],
#        [11.996,  3.316],
#        [11.9  ,  3.471],
#        [11.806,  3.626],
#        [11.712,  3.799],
#        [11.623,  3.952],
#        [11.549,  4.11 ],
#        [11.82 ,  4.397],
#        [12.594,  4.913],
#        [13.583,  5.524],
#        [12.301,  2.735],
#        [12.216,  2.918],
#        [12.104,  3.073],
#        [12.029,  3.236],
#        [11.928,  3.411],
#        [11.837,  3.567],
#        [11.707,  3.709],
#        [11.637,  3.869],
#        [11.496,  4.023],
#        [11.468,  4.196],
#        [12.174,  4.649],
#        [13.132,  5.251],
#        [14.371,  5.98 ],
#        [12.316,  2.816],
#        [12.21 ,  2.973],
#        [12.095,  3.127],
#        [11.985,  3.3  ],
#        [11.853,  3.445],
#        [11.754,  3.597],
#        [11.717,  3.788],
#        [11.617,  3.937],
#        [11.543,  4.095],
#        [11.734,  4.351],
#        [12.546,  4.88 ],
#        [13.667,  5.542],
#        [12.233,  2.791],
#        [12.186,  3.003],
#        [12.082,  3.179],
#        [11.974,  3.333],
#        [11.882,  3.489],
#        [11.78 ,  3.661],
#        [11.693,  3.816],
#        [11.57 ,  3.958],
#        [11.483,  4.111],
#        [12.463,  4.703],
#        [12.971,  5.128],
#        [14.268,  5.872],
#        [12.275,  2.984],
#        [12.139,  3.134],
#        [12.061,  3.296],
#        [11.938,  3.444],
#        [11.854,  3.623],
#        [11.757,  3.775],
#        [11.681,  3.934],
#        [11.776,  4.194],
#        [11.787,  4.408],
#        [13.271,  5.278],
#        [14.546,  6.028],
#        [12.257,  2.93 ],
#        [12.152,  3.087],
#        [12.037,  3.26 ],
#        [11.954,  3.419],
#        [11.843,  3.57 ],
#        [11.765,  3.729],
#        [11.671,  3.902],
#        [11.489,  4.023],
#        [11.536,  4.223],
#        [12.862,  5.005],
#        [14.4  ,  5.888],
#        [12.23 ,  2.83 ],
#        [12.132,  3.008],
#        [11.992,  3.154],
#        [11.899,  3.31 ],
#        [11.79 ,  3.46 ],
#        [11.708,  3.636],
#        [11.619,  3.79 ],
#        [11.555,  3.95 ],
#        [11.492,  4.131],
#        [12.086,  4.54 ],
#        [15.223,  5.973],
#        [14.507,  5.929],
#        [15.078,  6.442],
#        [12.489,  2.935],
#        [12.512,  3.127],
#        [11.494,  3.976],
#        [11.502,  4.161],
#        [12.23 ,  4.619],
#        [14.572,  5.735],
#        [14.491,  5.968],
#        [12.748,  3.119],
#        [12.97 ,  3.39 ],
#        [14.366,  3.976],
#        [12.171,  3.55 ],
#        [14.266,  4.411],
#        [14.172,  4.602],
#        [11.645,  4.001],
#        [12.005,  4.316],
#        [12.092,  4.563],
#        [13.908,  5.479],
#        [13.827,  5.674],
#        [12.74 ,  3.087],
#        [13.234,  3.404],
#        [13.616,  3.731],
#        [13.579,  3.928],
#        [13.494,  4.111],
#        [13.438,  4.302],
#        [13.379,  4.516],
#        [13.321,  4.707],
#        [11.954,  4.418],
#        [13.227,  5.099],
#        [12.831,  3.086],
#        [13.202,  3.375],
#        [13.199,  3.596],
#        [13.09 ,  3.765],
#        [13.054,  3.956],
#        [13.003,  4.142],
#        [12.966,  4.356],
#        [12.913,  4.542],
#        [11.993,  4.408],
#        [12.79 ,  4.932],
#        [12.704,  2.98 ],
#        [12.649,  3.156],
#        [12.59 ,  3.331],
#        [12.54 ,  3.508],
#        [12.462,  3.699],
#        [12.435,  3.883],
#        [12.362,  4.053],
#        [12.299,  4.247],
#        [12.241,  4.422],
#        [12.17 ,  4.592]], dtype=float32)

# %%
# https://github.com/alexstaravoitau/KITTI-Dataset/blob/master/kitti-dataset.ipynb
# points == velo_frame

def draw_point_cloud(ax, velo_frame, title=None, axes=[0, 1, 2], point_size=0.1, xlim3d=None, ylim3d=None, zlim3d=None):
        """
        Convenient method for drawing various point cloud projections as a part of frame statistics.
        """
        axes_limits = [
                        [-20, 80], # X axis range
                        [-20, 20], # Y axis range
                        [-3, 3]   # Z axis range
                    ]
        axes_str = ['X', 'Y', 'Z']
        ax.grid(False)

    
        ax.scatter(*np.transpose(velo_frame[:, axes]), s=point_size)
        # ax.set_title(title)
        ax.set_xlabel('{} axis'.format(axes_str[axes[0]]))
        ax.set_ylabel('{} axis'.format(axes_str[axes[1]]))
        if len(axes) > 2:
            ax.set_xlim3d(*axes_limits[axes[0]])
            ax.set_ylim3d(*axes_limits[axes[1]])
            ax.set_zlim3d(*axes_limits[axes[2]])
            ax.set_zlabel('{} axis'.format(axes_str[axes[2]]))
        else:
            ax.set_xlim(*axes_limits[axes[0]])
            ax.set_ylim(*axes_limits[axes[1]])
        # User specified limits
        if xlim3d!=None:
            ax.set_xlim3d(xlim3d)
        if ylim3d!=None:
            ax.set_ylim3d(ylim3d)
        if zlim3d!=None:
            ax.set_zlim3d(zlim3d)
        

fig, ax = plt.subplots(figsize=(20,10))
draw_point_cloud(ax, points_in_box, axes=[0, 1])
draw_box(ax, corners_3d_velo, axes=[0,1], color='r')
draw_box(ax, ego_car_bbx.T, axes=[0,1],color='b')
plt.plot(ego_car_point[:1], marker='o')

# %%
# Calculate distances
ego_car_point_2d = ego_car_point[:2]
distances = np.linalg.norm(points_in_box - ego_car_point_2d, axis=1)

# Find the index of the point with the shortest distance
index_of_shortest_distance = np.argmin(distances)
shortest_distance = distances[index_of_shortest_distance]
closest_point = points_in_box[index_of_shortest_distance]
closest_point = np.concatenate((closest_point, np.array([0])))

print(f"Shortest distance: {shortest_distance}")
print(f"Closest point: {closest_point}")
# Out:
# Shortest distance: 12.16226223028042
# Closest point: [11.49400043  3.97600007  0.        ]

# %%
closest_point
# Out:
# array([11.494,  3.976], dtype=float32)

# %% [markdown]
# ## Calculation 3: 3D point in polyhedron (Convexhull)

# %%
from scipy.spatial import ConvexHull

def in_hull(p, hull):
    """
    Test if points in `p` are in `hull`

    `p` should be a `NxK` coordinates of `N` points in `K` dimensions
    `hull` is either a scipy.spatial.Delaunay object or the `MxK` array of the 
    coordinates of `M` points in `K`dimensions for which Delaunay triangulation
    will be computed
    """
    from scipy.spatial import Delaunay
    if not isinstance(hull,Delaunay):
        hull = Delaunay(hull)

    return hull.find_simplex(p)>=0

# %%
hull = corners_3d_velo.T
hull
# Out:
# array([[15.12424719,  6.49985556, -1.70710774],
#        [16.06928938,  4.9406537 , -1.71370686],
#        [12.27779014,  2.64287284, -1.7776097 ],
#        [11.33274795,  4.2020747 , -1.77101058],
#        [15.10334837,  6.47872485,  0.29267156],
#        [16.04839056,  4.91952299,  0.28607244],
#        [12.25689133,  2.62174213,  0.2221696 ],
#        [11.31184914,  4.18094399,  0.22876872]])

# %%
points_in_box = []

for point in velo_frame[::5][:,:3]:
    if in_hull(point, hull):
        # print(point)
        points_in_box.append(point)

points_in = np.array(points_in)  # Convert the list of points to a NumPy array

# %%
points_in_box
# Out:
# [array([12.354,  3.113,  0.106], dtype=float32),
#  array([12.246,  3.271,  0.106], dtype=float32),
#  array([12.157,  3.432,  0.106], dtype=float32),
#  array([12.046,  3.606,  0.107], dtype=float32),
#  array([11.955,  3.764,  0.107], dtype=float32),
#  array([11.872,  3.923,  0.107], dtype=float32),
#  array([11.788,  4.102,  0.108], dtype=float32),
#  array([12.376,  4.502,  0.102], dtype=float32),
#  array([1.338e+01, 3.564e+00, 1.100e-02], dtype=float32),
#  array([1.4037e+01, 3.9540e+00, 1.0000e-03], dtype=float32),
#  array([ 1.4818e+01,  4.5290e+00, -1.2000e-02], dtype=float32),
#  array([ 1.4758e+01,  4.7400e+00, -1.2000e-02], dtype=float32),
#  array([ 1.4692e+01,  4.9490e+00, -1.2000e-02], dtype=float32),
#  array([11.968,  4.301,  0.027], dtype=float32),
#  array([12.77 ,  4.796,  0.014], dtype=float32),
#  array([ 1.3831e+01,  5.4460e+00, -3.0000e-03], dtype=float32),
#  array([12.619,  3.011, -0.067], dtype=float32),
#  array([14.426,  4.068, -0.109], dtype=float32),
#  array([11.734,  4.146, -0.056], dtype=float32),
#  array([14.307,  5.663, -0.118], dtype=float32),
#  array([12.593,  2.994, -0.133], dtype=float32),
#  array([14.429,  4.089, -0.186], dtype=float32),
#  array([14.203,  4.437, -0.183], dtype=float32),
#  array([12.874,  4.903, -0.154], dtype=float32),
#  array([14.404,  5.83 , -0.2  ], dtype=float32),
#  array([12.196,  2.892, -0.197], dtype=float32),
#  array([12.658,  3.381, -0.215], dtype=float32),
#  array([13.419,  3.81 , -0.242], dtype=float32),
#  array([12.444,  3.768, -0.212], dtype=float32),
#  array([13.159,  4.187, -0.238], dtype=float32),
#  array([12.217,  4.123, -0.208], dtype=float32),
#  array([11.596,  4.18 , -0.19 ], dtype=float32),
#  array([14.422,  5.762, -0.293], dtype=float32),
#  array([12.522,  2.878, -0.291], dtype=float32),
#  array([12.758,  3.251, -0.304], dtype=float32),
#  array([12.533,  3.383, -0.296], dtype=float32),
#  array([13.435,  3.879, -0.335], dtype=float32),
#  array([12.403,  3.834, -0.296], dtype=float32),
#  array([13.115,  4.26 , -0.328], dtype=float32),
#  array([11.673,  4.095, -0.273], dtype=float32),
#  array([12.129,  4.493, -0.295], dtype=float32),
#  array([13.627,  5.42 , -0.361], dtype=float32),
#  array([14.852,  6.209, -0.417], dtype=float32),
#  array([13.415,  3.349, -0.411], dtype=float32),
#  array([12.675,  3.378, -0.38 ], dtype=float32),
#  array([13.416,  3.823, -0.417], dtype=float32),
#  array([12.441,  3.781, -0.375], dtype=float32),
#  array([13.189,  4.211, -0.412], dtype=float32),
#  array([12.19 ,  4.17 , -0.369], dtype=float32),
#  array([12.857,  4.922, -0.409], dtype=float32),
#  array([14.374,  5.838, -0.486], dtype=float32),
#  array([12.442,  2.845, -0.437], dtype=float32),
#  array([12.705,  3.244, -0.455], dtype=float32),
#  array([12.589,  3.425, -0.452], dtype=float32),
#  array([12.459,  3.58 , -0.448], dtype=float32),
#  array([12.044,  3.686, -0.429], dtype=float32),
#  array([12.139,  3.904, -0.437], dtype=float32),
#  array([12.159,  4.123, -0.441], dtype=float32),
#  array([11.795,  4.269, -0.426], dtype=float32),
#  array([13.22 ,  5.216, -0.51 ], dtype=float32),
#  array([12.34 ,  2.816, -0.513], dtype=float32),
#  array([12.233,  2.974, -0.509], dtype=float32),
#  array([12.132,  3.132, -0.506], dtype=float32),
#  array([12.029,  3.308, -0.503], dtype=float32),
#  array([11.905,  3.496, -0.499], dtype=float32),
#  array([11.816,  3.652, -0.496], dtype=float32),
#  array([11.72 ,  3.805, -0.494], dtype=float32),
#  array([11.638,  3.981, -0.493], dtype=float32),
#  array([11.584,  4.147, -0.493], dtype=float32),
#  array([12.089,  4.52 , -0.527], dtype=float32),
#  array([12.905,  5.055, -0.581], dtype=float32),
#  array([13.999,  5.711, -0.652], dtype=float32),
#  array([12.371,  2.828, -0.582], dtype=float32),
#  array([12.268,  2.988, -0.578], dtype=float32),
#  array([12.144,  3.16 , -0.574], dtype=float32),
#  array([12.044,  3.317, -0.57 ], dtype=float32),
#  array([11.941,  3.47 , -0.567], dtype=float32),
#  array([11.864,  3.651, -0.565], dtype=float32),
#  array([11.771,  3.805, -0.563], dtype=float32),
#  array([11.68 ,  3.959, -0.56 ], dtype=float32),
#  array([11.599,  4.115, -0.559], dtype=float32),
#  array([11.912,  4.439, -0.584], dtype=float32),
#  array([12.707,  4.943, -0.641], dtype=float32),
#  array([13.749,  5.576, -0.715], dtype=float32),
#  array([12.344,  2.816, -0.669], dtype=float32),
#  array([12.22 ,  2.991, -0.663], dtype=float32),
#  array([12.125,  3.15 , -0.66 ], dtype=float32),
#  array([12.013,  3.303, -0.655], dtype=float32),
#  array([11.904,  3.476, -0.651], dtype=float32),
#  array([11.818,  3.632, -0.649], dtype=float32),
#  array([11.725,  3.786, -0.646], dtype=float32),
#  array([11.639,  3.941, -0.643], dtype=float32),
#  array([11.568,  4.121, -0.643], dtype=float32),
#  array([11.825,  4.401, -0.666], dtype=float32),
#  array([12.61 ,  4.895, -0.729], dtype=float32),
#  array([13.575,  5.514, -0.806], dtype=float32),
#  array([12.431,  2.8  , -0.737], dtype=float32),
#  array([12.301,  2.954, -0.731], dtype=float32),
#  array([12.19 ,  3.11 , -0.725], dtype=float32),
#  array([12.08 ,  3.285, -0.721], dtype=float32),
#  array([11.983,  3.441, -0.717], dtype=float32),
#  array([11.889,  3.596, -0.714], dtype=float32),
#  array([11.797,  3.751, -0.711], dtype=float32),
#  array([11.707,  3.926, -0.708], dtype=float32),
#  array([11.624,  4.082, -0.706], dtype=float32),
#  array([11.707,  4.298, -0.717], dtype=float32),
#  array([12.434,  4.79 , -0.78 ], dtype=float32),
#  array([13.401,  5.383, -0.863], dtype=float32),
#  array([14.754,  6.174, -0.977], dtype=float32),
#  array([12.261,  2.895, -0.81 ], dtype=float32),
#  array([12.16 ,  3.073, -0.805], dtype=float32),
#  array([12.046,  3.226, -0.799], dtype=float32),
#  array([12.131,  3.434, -0.81 ], dtype=float32),
#  array([11.845,  3.575, -0.791], dtype=float32),
#  array([11.728,  3.742, -0.786], dtype=float32),
#  array([11.65 ,  3.899, -0.784], dtype=float32),
#  array([11.569,  4.055, -0.782], dtype=float32),
#  array([11.62 ,  4.279, -0.792], dtype=float32),
#  array([12.329,  4.737, -0.858], dtype=float32),
#  array([13.337,  5.34 , -0.951], dtype=float32),
#  array([14.825,  6.231, -1.089], dtype=float32),
#  array([12.328,  2.831, -0.886], dtype=float32),
#  array([12.202,  2.984, -0.879], dtype=float32),
#  array([12.104,  3.142, -0.874], dtype=float32),
#  array([11.996,  3.316, -0.869], dtype=float32),
#  array([11.9  ,  3.471, -0.865], dtype=float32),
#  array([11.806,  3.626, -0.861], dtype=float32),
#  array([11.712,  3.799, -0.857], dtype=float32),
#  array([11.623,  3.952, -0.854], dtype=float32),
#  array([11.549,  4.11 , -0.853], dtype=float32),
#  array([11.82 ,  4.397, -0.883], dtype=float32),
#  array([12.594,  4.913, -0.961], dtype=float32),
#  array([13.583,  5.524, -1.06 ], dtype=float32),
#  array([12.301,  2.735, -0.957], dtype=float32),
#  array([12.216,  2.918, -0.953], dtype=float32),
#  array([12.104,  3.073, -0.947], dtype=float32),
#  array([12.029,  3.236, -0.944], dtype=float32),
#  array([11.928,  3.411, -0.939], dtype=float32),
#  array([11.837,  3.567, -0.935], dtype=float32),
#  array([11.707,  3.709, -0.928], dtype=float32),
#  array([11.637,  3.869, -0.926], dtype=float32),
#  array([11.496,  4.023, -0.918], dtype=float32),
#  array([11.468,  4.196, -0.921], dtype=float32),
#  array([12.174,  4.649, -0.997], dtype=float32),
#  array([13.132,  5.251, -1.099], dtype=float32),
#  array([14.371,  5.98 , -1.23 ], dtype=float32),
#  array([12.316,  2.816, -1.041], dtype=float32),
#  array([12.21 ,  2.973, -1.034], dtype=float32),
#  array([12.095,  3.127, -1.027], dtype=float32),
#  array([11.985,  3.3  , -1.021], dtype=float32),
#  array([11.853,  3.445, -1.012], dtype=float32),
#  array([11.754,  3.597, -1.007], dtype=float32),
#  array([11.717,  3.788, -1.009], dtype=float32),
#  array([11.617,  3.937, -1.004], dtype=float32),
#  array([11.543,  4.095, -1.003], dtype=float32),
#  array([11.734,  4.351, -1.029], dtype=float32),
#  array([12.546,  4.88 , -1.122], dtype=float32),
#  array([13.667,  5.542, -1.248], dtype=float32),
#  array([12.233,  2.791, -1.109], dtype=float32),
#  array([12.186,  3.003, -1.11 ], dtype=float32),
#  array([12.082,  3.179, -1.104], dtype=float32),
#  array([11.974,  3.333, -1.097], dtype=float32),
#  array([11.882,  3.489, -1.092], dtype=float32),
#  array([11.78 ,  3.661, -1.087], dtype=float32),
#  array([11.693,  3.816, -1.084], dtype=float32),
#  array([11.57 ,  3.958, -1.076], dtype=float32),
#  array([11.483,  4.111, -1.073], dtype=float32),
#  array([12.463,  4.703, -1.19 ], dtype=float32),
#  array([12.971,  5.128, -1.256], dtype=float32),
#  array([14.268,  5.872, -1.41 ], dtype=float32),
#  array([12.275,  2.984, -1.201], dtype=float32),
#  array([12.139,  3.134, -1.191], dtype=float32),
#  array([12.061,  3.296, -1.187], dtype=float32),
#  array([11.938,  3.444, -1.178], dtype=float32),
#  array([11.854,  3.623, -1.175], dtype=float32),
#  array([11.757,  3.775, -1.17 ], dtype=float32),
#  array([11.681,  3.934, -1.167], dtype=float32),
#  array([11.776,  4.194, -1.187], dtype=float32),
#  array([11.787,  4.408, -1.196], dtype=float32),
#  array([13.271,  5.278, -1.384], dtype=float32),
#  array([14.546,  6.028, -1.546], dtype=float32),
#  array([12.257,  2.93 , -1.275], dtype=float32),
#  array([12.152,  3.087, -1.268], dtype=float32),
#  array([12.037,  3.26 , -1.26 ], dtype=float32),
#  array([11.954,  3.419, -1.256], dtype=float32),
#  array([11.843,  3.57 , -1.248], dtype=float32),
#  array([11.765,  3.729, -1.245], dtype=float32),
#  array([11.671,  3.902, -1.241], dtype=float32),
#  array([11.489,  4.023, -1.225], dtype=float32),
#  array([11.536,  4.223, -1.238], dtype=float32),
#  array([12.862,  5.005, -1.416], dtype=float32),
#  array([14.4  ,  5.888, -1.621], dtype=float32),
#  array([12.23 ,  2.83 , -1.342], dtype=float32),
#  array([12.132,  3.008, -1.335], dtype=float32),
#  array([11.992,  3.154, -1.323], dtype=float32),
#  array([11.899,  3.31 , -1.317], dtype=float32),
#  array([11.79 ,  3.46 , -1.309], dtype=float32),
#  array([11.708,  3.636, -1.306], dtype=float32),
#  array([11.619,  3.79 , -1.301], dtype=float32),
#  array([11.555,  3.95 , -1.3  ], dtype=float32),
#  array([11.492,  4.131, -1.3  ], dtype=float32),
#  array([12.086,  4.54 , -1.386], dtype=float32),
#  array([12.489,  2.935, -1.442], dtype=float32),
#  array([12.512,  3.127, -1.45 ], dtype=float32),
#  array([11.958,  3.17 , -1.383], dtype=float32),
#  array([11.494,  3.976, -1.356], dtype=float32),
#  array([11.502,  4.161, -1.365], dtype=float32),
#  array([12.23 ,  4.619, -1.473], dtype=float32),
#  array([12.748,  3.119, -1.571], dtype=float32),
#  array([12.97 ,  3.39 , -1.609], dtype=float32),
#  array([12.171,  3.55 , -1.511], dtype=float32),
#  array([11.645,  4.001, -1.462], dtype=float32),
#  array([12.005,  4.316, -1.521], dtype=float32),
#  array([12.092,  4.563, -1.544], dtype=float32),
#  array([12.74 ,  3.087, -1.657], dtype=float32),
#  array([13.234,  3.404, -1.736], dtype=float32),
#  array([11.954,  4.418, -1.606], dtype=float32),
#  array([12.831,  3.086, -1.73 ], dtype=float32),
#  array([11.993,  4.408, -1.668], dtype=float32)]

# %%
# https://github.com/alexstaravoitau/KITTI-Dataset/blob/master/kitti-dataset.ipynb
# points == velo_frame

def draw_point_cloud(ax, velo_frame, title=None, axes=[0, 1, 2], point_size=0.1, xlim3d=None, ylim3d=None, zlim3d=None):
        """
        Convenient method for drawing various point cloud projections as a part of frame statistics.
        """
        axes_limits = [
                        [-20, 80], # X axis range
                        [-20, 20], # Y axis range
                        [-3, 3]   # Z axis range
                    ]
        axes_str = ['X', 'Y', 'Z']
        ax.grid(False)

    
        ax.scatter(*np.transpose(velo_frame[:, axes]), s=point_size)
        # ax.set_title(title)
        ax.set_xlabel('{} axis'.format(axes_str[axes[0]]))
        ax.set_ylabel('{} axis'.format(axes_str[axes[1]]))
        if len(axes) > 2:
            ax.set_xlim3d(*axes_limits[axes[0]])
            ax.set_ylim3d(*axes_limits[axes[1]])
            ax.set_zlim3d(*axes_limits[axes[2]])
            ax.set_zlabel('{} axis'.format(axes_str[axes[2]]))
        else:
            ax.set_xlim(*axes_limits[axes[0]])
            ax.set_ylim(*axes_limits[axes[1]])
        # User specified limits
        if xlim3d!=None:
            ax.set_xlim3d(xlim3d)
        if ylim3d!=None:
            ax.set_ylim3d(ylim3d)
        if zlim3d!=None:
            ax.set_zlim3d(zlim3d)
        


fig = plt.figure(figsize=(20,10))
ax = fig.add_subplot(111,projection='3d')
ax.view_init(40,150)
draw_point_cloud(ax, points_in)
draw_box(ax, corners_3d_velo)

# %%
# calculate
ego_point = np.array([[0,0,0]])
ego_point_in_velo = calib.project_rect_to_velo(ego_point)
ego_point_in_velo

# Calculate distances
distances = np.linalg.norm(points_in_box - ego_point_in_velo, axis=1)
# Find the index of the point with the shortest distance
index_of_shortest_distance = np.argmin(distances)
shortest_distance = distances[index_of_shortest_distance]
print(f"Shortest distance: {shortest_distance}")
print(f"Closest point: {points_in_box[index_of_shortest_distance]}")
# Out:
# Shortest distance: 11.9529707868339
# Closest point: [11.496  4.023 -0.918]

# %%
fig = plt.figure(figsize=(20,10))
ax = fig.add_subplot(111,projection='3d')
ax.view_init(40,150)
draw_point_cloud(ax, np.array([points_in_box[index_of_shortest_distance]]))
draw_box(ax, corners_3d_velo)

# %%
from scipy.spatial import ConvexHull, Delaunay

def point_in_hull(p, hull):
    """
    Test if points in `p` are in `hull`

    `p` should be a `NxK` coordinates of `N` points in `K` dimensions
    `hull` is either a scipy.spatial.Delaunay object or the `MxK` array of the 
    coordinates of `M` points in `K`dimensions for which Delaunay triangulation
    will be computed
    """
    if not isinstance(hull,Delaunay):
        hull = Delaunay(hull)
    return hull.find_simplex(p)>=0

def compute_3d_box_cam2(h,w,l,x,y,z,yaw):
    '''
    Return: 3xn in cam2 coordinates
    https://github.com/bostondiditeam/kitti/blob/master/resources/devkit_object/readme.txt
    '''
    R = np.array([[np.cos(yaw),0,np.sin(yaw)], [0,1,0], [-np.sin(yaw),0,np.cos(yaw)]])
    x_corners = [l/2,l/2,-l/2,-l/2,l/2,l/2,-l/2,-l/2]
    y_corners = [0,0,0,0,-h,-h,-h,-h]
    z_corners = [w/2,-w/2,-w/2,w/2,w/2,-w/2,-w/2,w/2]
    corners_3d_cam2 = np.dot(R, np.vstack([x_corners, y_corners, z_corners]))
    corners_3d_cam2 += np.vstack([x,y,z])
    return corners_3d_cam2

# %%
frame = 0

while frame < 155:
    df_tracking_frame = df_tracking[df_tracking.frame==frame]
    point_cloud = read_point_cloud(os.path.join(DATA_PATH, 'velodyne_points/data/%010d.bin'%frame))
    boxes_3d = np.array(df_tracking_frame[['height','width','length','pos_x','pos_y','pos_z','rot_y']])
    corners_3d_velos = []
    for box_3d in boxes_3d:
        corners_3d_cam2 = compute_3d_box_cam2(*box_3d) # calcualte the corners
        corners_3d_velo = calib.project_rect_to_velo(corners_3d_cam2.T) # convert to velo, 8*3 array
        corners_3d_velos += [corners_3d_velo]
    
        # judge if point in box_3d
        points_in_box = []
        hull = np.array([[box_3d]]).T
        for point in point_cloud[::5][:,:3]:
            if point_in_hull(point, hull):
                points_in_box.append(point)
        
        # calculate the point with shortest distance to ego 
        ego_point = np.array([[0,0,0]])
        ego_point_in_velo = calib.project_rect_to_velo(ego_point)
        ego_point_in_velo
        # Calculate distances
        distances = np.linalg.norm(points_in_box - ego_point_in_velo, axis=1)
        # Find the index of the point with the shortest distance
        index_of_shortest_distance = np.argmin(distances)
        shortest_distance = distances[index_of_shortest_distance]
        print(f"Shortest distance: {shortest_distance}")
        # print(f"Closest point: {points_in_box[index_of_shortest_distance]}")


    frame += 1
